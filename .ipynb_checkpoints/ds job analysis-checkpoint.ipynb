# %% [markdown]
# # Data Scientist Job In United States

# %% [markdown]
# This data set covers the job listings for Data Scientists in the United States from May 2018 through October 2019.
#
# * There are 10,000 jobs scraped from JobsPikr website.
# * Information collected are: company name, job title, location, job description, url,
#   job type (part/full time), and post dated.
# * I used DataFrame in python and the data show that California have the most data scientist job listing; around 1485.
# * Illinois 403 and Missouri 121 job listing.

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
#import data into DataFrame
df = pd.read_csv('ds_job_posting.csv')
df = pd.DataFrame(df)

# %%
pd.set_option('max_columns', None)
df.head((5))
# Out:
#              crawl_timestamp  \
# 0  2019-02-06 05:26:22 +0000
# 1  2019-02-06 05:33:41 +0000
# 2  2019-02-06 05:33:35 +0000
# 3  2019-02-06 05:33:42 +0000
# 4  2019-02-06 05:48:23 +0000
#
#                                                  url  \
# 0  https://www.indeed.com/viewjob?jk=fd83355c2b23...
# 1  https://www.dice.com/jobs/detail/Data-Scientis...
# 2  https://www.dice.com/jobs/detail/Data-Scientis...
# 3  https://www.indeed.com/viewjob?jk=841edd86ead2...
# 4  https://job-openings.monster.com/senior-data-s...
#
#                                            job_title            category  \
# 0                        Enterprise Data Scientist I  Accounting/Finance
# 1                                     Data Scientist                 NaN
# 2                                     Data Scientist                 NaN
# 3  Data Scientist, Aladdin Wealth Tech, Associate...  Accounting/Finance
# 4                              Senior Data Scientist             biotech
#
#                            company_name            city  \
# 0               Farmers Insurance Group  Woodland Hills
# 1                        Luxoft USA Inc      Middletown
# 2  Cincinnati Bell Technology Solutions        New York
# 3                             BlackRock        New York
# 4                           CyberCoders       Charlotte
#
#                      state country   inferred_city  inferred_state  \
# 0                       CA     Usa  Woodland hills      California
# 1                       NJ     Usa      Middletown      New jersey
# 2                       NY     Usa        New york        New york
# 3  NY 10055 (Midtown area)     Usa        New york        New york
# 4                       NC     Usa       Charlotte  North carolina
#
#   inferred_country   post_date  \
# 0              Usa  2019-02-06
# 1              Usa  2019-02-05
# 2              Usa  2019-02-05
# 3              Usa  2019-02-06
# 4              Usa  2019-02-05
#
#                                      job_description   job_type  \
# 0  Read what people are saying about working here...  Undefined
# 1  We have an immediate opening for a Sharp Data ...  Undefined
# 2  Candidates should have the following backgroun...  Full Time
# 3  Read what people are saying about working here...  Undefined
# 4  We are seeking an extraordinary Data Scientist...  Full Time
#
#   salary_offered job_board  geo            cursor  contact_email  \
# 0            NaN    indeed  usa  1549432819114777            NaN
# 1            NaN      dice  usa  1549432819122106            NaN
# 2            NaN      dice  usa  1549432819236156            NaN
# 3            NaN    indeed  usa  1549432819259473            NaN
# 4            NaN   monster  usa  1549436429015957            NaN
#
#   contact_phone_number                           uniq_id html_job_description
# 0                  NaN  3b6c6acfcba6135a31c83bd7ea493b18                  NaN
# 1                  NaN  741727428839ae7ada852eebef29b0fe                  NaN
# 2                  NaN  cdc9ef9a1de327ccdc19cc0d07dbbb37                  NaN
# 3                  NaN  1c8541cd2c2c924f9391c7d3f526f64e                  NaN
# 4                  NaN  445652a560a5441060857853cf267470                  NaN

# %% [markdown]
# # Data Cleaning
# Remove column by using drop()function

# %%
#remove columns crawl_timestamp, inferred_city,state,country, and colums with NaN. Didn't remove job_description and phone_number because it have data in some rows.

df.drop(['crawl_timestamp','geo', 'contact_email', 'job_description','inferred_city','cursor','inferred_state','inferred_country','salary_offered','html_job_description'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['url', 'job_title', 'category', 'company_name', 'city', 'state',
#        'country', 'post_date', 'job_type', 'job_board', 'contact_phone_number',
#        'uniq_id'],
#       dtype='object')

# %% [markdown]
# ## Simplifying Postion
# Using elif statement to narrow down job title and seniority

# %%
#simplify postions to a smaller spectrum by making new a new column 'position simpl'

def position_separation(job_title):
    if 'data scientist' in job_title.lower():
        return 'data scientist'
    elif 'data engineer'in job_title.lower():
        return 'data engineer'
    elif 'analyst' in job_title.lower():
        return 'analyst'
    elif 'deep learning' in job_title.lower():
        return 'deep learning'
    elif 'machine learning engineer'in job_title.lower():
        return 'mle'
    elif 'manger'in job_title.lower():
        return 'director'
    else: return 'na'

# %%
# defining seniority and adding new column as 'ranking'
def ranking(job_title):
    if 'sr' in job_title.lower()or 'senior' in job_title.lower()or 'sr' in job_title.lower()or 'lead' in job_title.lower()or 'principal' in job_title.lower():
        return 'senior'
    elif 'jr' in job_title.lower() or 'jr.' in job_title.lower():
        return 'jr'
    else:
        return 'na'

# %% [markdown]
# ## Adding New Column Names

# %% [markdown]
# ### positon_simpl and ranking

# %%
df['position_simpl'] = df['job_title'].apply(position_separation)
#Total count for jobs that's looking for data scientist.
df.position_simpl.value_counts()
# Out:
# data scientist    9999
# analyst              1
# Name: position_simpl, dtype: int64

# %%
#Total count of ranking job required (jr,sen,and na)

df['ranking'] = df['job_title'].apply(ranking)
df.ranking.value_counts()
# Out:
# na        6907
# senior    3051
# jr          42
# Name: ranking, dtype: int64

# %% [markdown]
# ## Sort by element

# %%
 #sort by 'state' column; states are listed in alphabetical order.
df.sort_values(by='state')
# Out:
#                                                     url  \
# 7032  https://www.indeed.com/viewjob?jk=8e2c529ee750...
# 5637  https://www.indeed.com/viewjob?jk=f02ae215dee9...
# 7755  https://www.indeed.com/viewjob?jk=97f42388119e...
# 7775  https://www.indeed.com/viewjob?jk=4bf6472e888e...
# 5779  https://www.indeed.com/viewjob?jk=f52a816db67e...
# ...                                                 ...
# 9995              https://stackoverflow.com/jobs/271829
# 9996              https://stackoverflow.com/jobs/283895
# 9997              https://stackoverflow.com/jobs/293326
# 9998              https://stackoverflow.com/jobs/283895
# 9999              https://stackoverflow.com/jobs/283895
#
#                                               job_title  \
# 7032                  Data Scientist - Senior Associate
# 5637                                     Data Scientist
# 7755                                 Sr. Data Scientist
# 7775               Data Scientist and Team Lead, Senior
# 5779                               Data Scientist (NSS)
# ...                                                 ...
# 9995                                     Data Scientist
# 9996               Data Scientist, (Staff or Principal)
# 9997  Siri - Embedded Data Scientist, Data Organization
# 9998               Data Scientist, (Staff or Principal)
# 9999               Data Scientist, (Staff or Principal)
#
#                                 category  \
# 7032                Computer-or-internet
# 5637              Government-or-military
# 7755         Manufacturing-or-mechanical
# 7775         Manufacturing-or-mechanical
# 5779                Computer-or-internet
# ...                                  ...
# 9995                      Data Scientist
# 9996                      Data Scientist
# 9997  Data Scientist, Embedded Developer
# 9998                      Data Scientist
# 9999                      Data Scientist
#
#                                            company_name         city state  \
# 7032             Guidehouse 13 reviews - Huntsville, AL   Huntsville    AL
# 5637  Company Info Follow Get job updates from Regio...   Birmingham    AL
# 7755        Regions Bank 2,376 reviews - Birmingham, AL   Birmingham    AL
# 7775                  Booz Allen Hamilton 1,963 reviews   Huntsville    AL
# 5779                                             IDEMIA   Huntsville    AL
# ...                                                 ...          ...   ...
# 9995                                            Upstart     Columbus   NaN
# 9996                                        Realtor.com  Santa Clara   NaN
# 9997                                         Apple Inc.   Pittsburgh   NaN
# 9998                                        Realtor.com  Santa Clara   NaN
# 9999                                        Realtor.com  Santa Clara   NaN
#
#      country   post_date   job_type      job_board contact_phone_number  \
# 7032      US  2019-08-15  Undefined         indeed                  NaN
# 5637      US  2019-07-23  Undefined         indeed                  NaN
# 7755      US  2019-08-21  Undefined         indeed                  NaN
# 7775      US  2019-08-22  Undefined         indeed                  NaN
# 5779      US  2019-07-24  Undefined         indeed                  NaN
# ...      ...         ...        ...            ...                  ...
# 9995      US  2019-09-27  Full Time  Stackoverflow                  NaN
# 9996      US  2019-09-11  Full Time  Stackoverflow                  NaN
# 9997      US  2019-09-03  Full Time  Stackoverflow                  NaN
# 9998      US  2019-09-11  Full Time  Stackoverflow                  NaN
# 9999      US  2019-09-11  Full Time  Stackoverflow                  NaN
#
#                                uniq_id  position_simpl ranking
# 7032  088dba470d050c6b432681347d017026  data scientist  senior
# 5637  c444f21b57f743e1e6b674597099c5f0  data scientist      na
# 7755  5570a7eb8b7ab1fec23d0fcdfa681cd6  data scientist  senior
# 7775  6bf93c71837b89352156c8b9d09f31ae  data scientist  senior
# 5779  93378a2ee3ad3c7ed1c6ad02f46c0def  data scientist      na
# ...                                ...             ...     ...
# 9995  e9f2ca58c7abcd4553a4a0be9602312e  data scientist      na
# 9996  efe05f2364ee3df943e952bc68ed95a7  data scientist  senior
# 9997  b980054dbb6d3fe1c6a421a237d1495f  data scientist      na
# 9998  4b86da9d2b24b87ec3c815d9072ad616  data scientist  senior
# 9999  4cbe57f790e3346d7154b68c9370b7ef  data scientist  senior
#
# [10000 rows x 14 columns]

# %%
df.sort_values(by='post_date', ascending = False)
#newest post in oct 2019 
#oldest post in may 2018
# Out:
#                                                     url  \
# 9992  https://www.indeed.com/viewjob?jk=d4ffa48f3548...
# 9969  https://www.careerbuilder.com/job/J3W24867TTZV...
# 9971  https://job-openings.monster.com/associate-dat...
# 9955  https://job-openings.monster.com/data-scientis...
# 9956  https://job-openings.monster.com/principal-dat...
# ...                                                 ...
# 1223  https://job-openings.monster.com/data-scientis...
# 1429  https://job-openings.monster.com/data-scientis...
# 2087  https://job-openings.monster.com/data-scientis...
# 3492  https://job-openings.monster.com/data-scientis...
# 1433  https://job-openings.monster.com/data-scientis...
#
#                                               job_title  \
# 9992                         Geology/Geo-Data Scientist
# 9969                 Senior Data Scientist - Boston, MA
# 9971                           Associate Data Scientist
# 9955            Data Scientist/Principal Data Scientist
# 9956                           Principal Data Scientist
# ...                                                 ...
# 1223               Data Scientist - Operations Research
# 1429                                    Data Scientist*
# 2087  Data Scientist, Machine Learning for an Automo...
# 3492                      Data Scientist with Polygraph
# 1433                                     Data Scientist
#
#                          category                      company_name  \
# 9992  Engineering-or-architecture                        Albany, OR
# 9969                          NaN      Nigel Frank International US
# 9971                computer jobs                               AIC
# 9955                    math jobs                  Northrop Grumman
# 9956                    math jobs                  Northrop Grumman
# ...                           ...                               ...
# 1223                   automotive                           Carvana
# 1429                    math jobs  Odyssey Systems Consulting Group
# 2087                    math jobs                   OSI Engineering
# 3492          social science jobs                            Leidos
# 1433                    math jobs                               LRS
#
#                  city state country   post_date   job_type      job_board  \
# 9992           Albany    OR      US  2019-10-01  Undefined         indeed
# 9969           Boston    MA      US  2019-09-30  Full Time  careerbuilder
# 9971    Neptune Beach    FL     Usa  2019-09-30  Full Time        monster
# 9955  Rolling Meadows    IL     Usa  2019-09-30  Undefined        monster
# 9956        Melbourne    FL     Usa  2019-09-30  Undefined        monster
# ...               ...   ...     ...         ...        ...            ...
# 1223              NaN   NaN     Usa  2018-10-12  Undefined        monster
# 1429              NaN   NaN     Usa  2018-10-03  Undefined        monster
# 2087              NaN   NaN     Usa  2018-08-13  Full Time        monster
# 3492           MCLEAN    VA     Usa  2018-07-25  Undefined        monster
# 1433              NaN   NaN     Usa  2018-05-24  Undefined        monster
#
#      contact_phone_number                           uniq_id  position_simpl  \
# 9992                  NaN  02274ff2a44343f06fd31cce1feaab61  data scientist
# 9969                  NaN  3207f22e5c567f998307da1652d45f4a  data scientist
# 9971                  NaN  51505c25d32452edab456cef25e4e898  data scientist
# 9955                  NaN  cc8e86ac500ca05060d0efe51957c212  data scientist
# 9956                  NaN  ffcf966bf71dffa3412dd833ad04861a  data scientist
# ...                   ...                               ...             ...
# 1223                  NaN  5f500d59af80737196a1f994d0b1d5fa  data scientist
# 1429                  NaN  0aa952f7707ee5b3344b4c70d34a2d71  data scientist
# 2087                  NaN  50ee90c6bc79819d2bfd9a91cc34e34e  data scientist
# 3492                  NaN  619e9a215731fcabe095e05a62c07c13  data scientist
# 1433                  NaN  e1dc252a37132518dc3eeaf6efe5728e  data scientist
#
#      ranking
# 9992      na
# 9969  senior
# 9971      na
# 9955  senior
# 9956  senior
# ...      ...
# 1223      na
# 1429      na
# 2087      na
# 3492      na
# 1433      na
#
# [10000 rows x 14 columns]

# %% [markdown]
# # Top ten company ranked by job availability

# %%
co_name=pd.value_counts(df['company_name'])
co_name_1=pd.DataFrame(co_name)

# %%
co_name_1.head((10))
# Out:
#                                           company_name
# CyberCoders                                        628
# Jefferson Frank                                    259
# Nigel Frank International US                        88
# Taboola                                             77
# Booz Allen Hamilton                                 77
# Apex Systems                                        72
# Kforce Technology                                   71
# The Judge Group                                     67
# Social Science Research Solutions (SSRS)            67
# Robert Half Technology                              63

# %% [markdown]
# # Top states ranked by job availability

# %%
sta_name=pd.value_counts(df['state'])
sta_name_1=pd.DataFrame(sta_name)
sta_name_1.head((10))
# Out:
#     state
# CA   1485
# NY    569
# VA    511
# TX    494
# MA    477
# IL    403
# WA    344
# NJ    310
# PA    284
# MD    238

# %%
sta_name=pd.value_counts(df['state'])
sta_name_1=pd.DataFrame(sta_name)

# %% [markdown]
# # DS Job In Illinois and Missouri

# %%
#import data
job = pd.read_csv('ds_job_posting.csv')

# %%
# separtate il and mo from 'state'
# comparsion of job avaliable bewtween il and mo

#df.loc[df['state'].str.contains('IL')
df[df['state']=='IL']
IL= df[df['state']=='IL']
mo= df[df['state']=='MO']

# %%
# result of all job available in IL
IL
# Out:
#                                                     url  \
# 55    https://www.dice.com/jobs/detail/Sr-Data-Scien...
# 58    https://www.dice.com/jobs/detail/Data-Engineer...
# 111   https://www.dice.com/jobs/detail/Data-Scientis...
# 112   https://www.dice.com/jobs/detail/Machine-Learn...
# 115   https://www.dice.com/jobs/detail/Data-Scientis...
# ...                                                 ...
# 9833  https://www.theladders.com/job/principal-data-...
# 9846  https://www.careerbuilder.com/job/J3R7ZG6WNW6G...
# 9902  https://www.theladders.com/job/senior-regulato...
# 9955  https://job-openings.monster.com/data-scientis...
# 9960  https://www.careerbuilder.com/job/J3W0HL647TKL...
#
#                                               job_title  \
# 55                                    Sr Data Scientist
# 58    Data Engineer/Data Scientist (Python OR R AND ...
# 111                                      Data Scientist
# 112            Machine Learning Engineer/Data Scientist
# 115                       Data Scientist ( healthcare )
# ...                                                 ...
# 9833            Principal Data Scientist in Chicago, IL
# 9846  Chubb Global Risk Advisors\: Data Scientist Co...
# 9902    Senior Regulatory Data Scientist in Chicago, IL
# 9955            Data Scientist/Principal Data Scientist
# 9960            AWS Big Data - Data Scientist - Chicago
#
#                               category                        company_name  \
# 55                                 NaN                 IT Associates, Inc.
# 58                                 NaN                 IT Associates, Inc.
# 111                                NaN                         CyberCoders
# 112                                NaN              Medline Industries Inc
# 115                                NaN                 IT Associates, Inc.
# ...                                ...                                 ...
# 9833          Principal Data Scientist     Health Care Service Corporation
# 9846                               NaN  Chubb Group of Insurance Companies
# 9902  Senior Regulatory Data Scientist                           CME Group
# 9955                         math jobs                    Northrop Grumman
# 9960                               NaN                     Jefferson Frank
#
#                  city state country   post_date   job_type      job_board  \
# 55           Rosemont    IL     Usa  2019-02-06   Contract           dice
# 58        Des Plaines    IL     Usa  2019-02-06   Contract           dice
# 111      Melrose Park    IL     Usa  2019-02-07  Full Time           dice
# 112        Northfield    IL     Usa  2019-02-09  Full Time           dice
# 115          Rosemont    IL     Usa  2019-02-07   Contract           dice
# ...               ...   ...     ...         ...        ...            ...
# 9833          Chicago    IL      US  2019-09-26  Full Time            NaN
# 9846          Chicago    IL      US  2019-09-27  Full Time  careerbuilder
# 9902          Chicago    IL      US  2019-09-27  Full Time            NaN
# 9955  Rolling Meadows    IL     Usa  2019-09-30  Undefined        monster
# 9960          Chicago    IL      US  2019-09-30  Full Time  careerbuilder
#
#      contact_phone_number                           uniq_id  position_simpl  \
# 55                    NaN  00f16318041f2cfadde34758b93ef6fe  data scientist
# 58         (630) 717-8000  3e137043376d8dcdfc0d95b74592344e  data scientist
# 111                   NaN  1fab888130ff92e2be55e5e698b36919  data scientist
# 112                   NaN  8fedc5642ff6e8a5ca530f96db117322  data scientist
# 115                   NaN  6671a90039150dd68a4de45f038cedca  data scientist
# ...                   ...                               ...             ...
# 9833                  NaN  46edb770afa76c6848862d7fb8679538  data scientist
# 9846                  NaN  6e53cd62c84ea98a79066f1ded444384  data scientist
# 9902                  NaN  a76b82107395bdd84bd622285f726acd  data scientist
# 9955                  NaN  cc8e86ac500ca05060d0efe51957c212  data scientist
# 9960                  NaN  09ada0bbbe0f8a4e9d2986d96b0c7587  data scientist
#
#      ranking
# 55    senior
# 58        na
# 111       na
# 112       na
# 115       na
# ...      ...
# 9833  senior
# 9846      na
# 9902  senior
# 9955  senior
# 9960      na
#
# [403 rows x 14 columns]

# %%
state_count= [IL.shape[0],mo.shape[0]] 
state_count
# Out:
# [403, 121]

# %%
#create variable for IL and Mo for x-axis
state_name=['IL','MO']
state_name
# Out:
# ['IL', 'MO']

# %%
#use NumPy.arange() to find y-axis
yaxis = np.arange(len(state_name))

# %% [markdown]
# # Bar Graph
# ### Comparsion of job listing in Illinois and Missouri

# %%
state_count = [403,121]

plt.xticks(yaxis,state_name)
plt.title("DS Job In Illinois and Missouri")
plt.bar(yaxis,state_count, color= 'orange')
plt.ylabel('Job Available')
plt.xlabel('State')
# Out:
# Text(0.5, 0, 'State')

# %% [markdown]
# # Bar graph
# ### Top ten company ranked by job availability

# %%
x= ['CyberCoders','Jefferson Frank','Nigel Frank International', 'USTaboola Booz', 'Allen Hamilton', 'Apex Systems', 'Kforce Technology', 'The Judge Group', 'Social Science Research Solutions (SSRS)','Robert Half Technology']
job = [628, 259, 88, 77, 77, 72, 71, 67, 67, 63]

x_job = [i for i, _ in enumerate(x)]
plt.barh(x_job, job, color= 'orange')
plt.title('Top Ten Company Hiring Data Scientist')
plt.ylabel('Company')
plt.xlabel('Job Available')
plt.yticks(x_job, x)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Pie Graph
# ### Comparsion of job listing in Illinois and Missouri

# %%
plt.style.use('fivethirtyeight')
slices = [121,403]
labels = ['IL','MO',]
colors =['red','blue']
plt.pie(slices, labels=labels,autopct='%1.1f%%',
        wedgeprops={'edgecolor': 'black'})
plt.title('DS Job in IL & MO')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
job_post = {
    'title': ['Data Scientist','Senior Data Scientist','Sr. Data Scientist','Lead Data Scientist','Principal Data Scientist','Other'],
    'job': [2889,6440,203,178,148,320]
}

# %% [markdown]
# # Swam Plot
# ### Number of jobs that are avaliable in CA,NY,VA,TX,MA

# %%
new_job_post=pd.DataFrame(job_post)
new_job_post
# Out:
#                       title   job
# 0            Data Scientist  2889
# 1     Senior Data Scientist  6440
# 2        Sr. Data Scientist   203
# 3       Lead Data Scientist   178
# 4  Principal Data Scientist   148
# 5                     Other   320

# %%
sns.swarmplot(x='job', y='title', data= new_job_post)
# Out:
# <AxesSubplot:xlabel='job', ylabel='title'>

# %% [markdown]
# # Bar Graph
# ### Comparsion of job listing by job's titles

# %%
plt.style.use('fivethirtyeight')
slices = [2889,6440,178,148,320]
labels = ['Data Scientist','Senior Data Scientist','Lead Data Scientist','Principal Data Scientist','Other']
colors =['orange','blue']
plt.pie(slices, labels=labels,autopct='%1.1f%%',
        wedgeprops={'edgecolor': 'black'})
plt.title('Job Available By Titles')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
